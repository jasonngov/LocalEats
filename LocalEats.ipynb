# %% [markdown]
# # Local Eats
# > Mini project created to learn about FourSquare API and Folium. Learned how to utilize Pandas library to manipulate response data of FourSwaure API calls.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# WARNING: You are using pip version 20.3.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.
# Folium installed
# Libraries imported.

# %%
### Define Foursquare Credentials and Version
CLIENT_ID = 'INSERT CLIENT_ID' # your Foursquare ID
CLIENT_SECRET = 'INSERT CLIENT_SECRET' # your Foursquare Secret
ACCESS_TOKEN = 'INSERT ACCESS_TOKEN' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
# Out:
# Your credentails:
# CLIENT_ID: 3D5VPL5P0ZAWIC0YQLIC4G0JNOA1NXBW1JKCUWOMR3BBQAYJ
# CLIENT_SECRET:330Q4HMBYF1YFECCPKBD45LKERYNITE4AYQNVBM5GA25HO02

# %%
address = '1 S. Penn Square, Philadelphia, PA 19102'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.9508621 -75.1629441

# %%
search_query = 'Chinese'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Chinese .... OK!

# %%
### Identify route, and send the request
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
print(results)
# Out:
# {'meta': {'code': 200, 'requestId': '606b6c768b19694466c151c9'}, 'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}], 'response': {'venues': [{'id': '4c06864a8a81c9b6c1d12590', 'name': 'Chinese Food & Eggroll', 'location': {'address': 'Race Street', 'crossStreet': '15th Street', 'lat': 39.95242887947443, 'lng': -75.1656335696158, 'labeledLatLngs': [{'label': 'display', 'lat': 39.95242887947443, 'lng': -75.1656335696158}], 'distance': 288, 'postalCode': '19102', 'cc': 'US', 'city': 'Philadelphia', 'state': 'PA', 'country': 'United States', 'formattedAddress': ['Race Street (15th Street)', 'Philadelphia, PA 19102']}, 'categories': [{'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1617652854', 'hasPerk': False}, {'id': '4c9a4119292a6dcb0c5bcd76', 'name': 'Chinese Fastwo
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                             name  \
# 0  4c06864a8a81c9b6c1d12590           Chinese Food & Eggroll
# 1  4c9a4119292a6dcb0c5bcd76                  Chinese Fastwok
# 2  4f326fcb19836c91c7d7ab5b      Chinese Cuisine Susanna Foo
# 3  537e3891498e6cfcacc346cf  chinese food cart 16th & market
# 4  4bafe4c1f964a52092293ce3  Panda Garden Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1617652854    False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1617652854    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1617652854    False
# 3  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...  v-1617652854    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1617652854    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0      Race Street          15th Street     39.952429    -75.165634
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                       name                     categories  \
# 0                   Chinese Food & Eggroll                     Food Truck
# 1                          Chinese Fastwok             Chinese Restaurant
# 2              Chinese Cuisine Susanna Foo             Chinese Restaurant
# 3          chinese food cart 16th & market                     Food Truck
# 4          Panda Garden Chinese Restaurant             Chinese Restaurant
# 5             Chinese Cart 15th And Cherry             Chinese Restaurant
# 6                          Tien Bo Chinese             Chinese Restaurant
# 7                       Tg Chinese Cuisine             Chinese Restaurant
# 8                          Xu Sing Chinese  Vegetarian / Vegan Restaurant
# 9                        New Haven Chinese               Hunan Restaurant
# 10                      Trans Chinese Food                     Food Truck
# 11  18th & Market Chinese Food & Egg Rolls                     Food Truck
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent City Hall
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='City Hall',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the food trucks as blue circle markers
for lat, lng, name in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=name,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...
